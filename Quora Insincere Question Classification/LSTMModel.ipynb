# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import utils as utl
from collections import Counter
# Out:
# C:\Users\sitandon\AppData\Local\Continuum\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
import re
re.sub(r'\[math\]', ' LaTex math ', "a+b")
# Out:
# 'a+b'

# %%
index = 0
for o in open("./Data/embeddings/wiki-news-300d-1M/wiki-news-300d-1M.vec"):
    print(o)
    index +=1 
    if (index > 5):
        break;
# Out:
# 999994 300
#
# ...

# %%
from unicodedata import category, name, normalize

normalize('NFKD', "Ramis good bad boy".replace('ø', 'o').replace('Ø', 'O').replace('⁻', '-').replace('₋', '-'))
# Out:
# 'Ramis good bad boy'

# %%
train = pd.read_csv("./Data/trainCleansed.csv")
test = pd.read_csv("./Data/testCleansed.csv")

# %%
test.head()
# Out:
#                     qid                                      question_text  \
# 0  00014894849d00ba98a9  My voice range is A2-C5 <eos>  My chest voice ...
# 1  000156468431f09b3cae           How much does a tutor earn in Bangalore?
# 2  000227734433360e1aae  What are the best made pocket knives under $20...
# 3  0005e06fbe3045bd2a92  Why would they add a hypothetical scenario tha...
# 4  00068a0f7f41f50fc399   What is the dresscode for Techmahindra freshers?
#
#                                             wordList  countWords  \
# 0  ['voice', 'range', 'a2', 'c5', 'eos', 'chest',...          18
# 1  ['much', 'tutor', 'earn', 'bangalore', 'zerove...           4
# 2  ['best', 'made', 'pocket', 'knife', '200', '30...           6
# 3  ['would', 'add', 'hypothetical', 'scenario', '...          17
# 4  ['dresscode', 'techmahindra', 'fresher', 'zero...           3
#
#                                           WordIDList
# 0  [29914, 110059, 79699, 79517, 163680, 140719, ...
# ...
